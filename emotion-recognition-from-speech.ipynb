# %%
# ============================================================
# SPEECH EMOTION RECOGNITION - MODIFIED FULL PIPELINE
# RAVDESS DATASET
# Fixes prediction issue and improves training quality
# ============================================================

# =========================
# 1) SETUP
# =========================

import os
import json
import random
import warnings
warnings.filterwarnings("ignore")

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import librosa

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_recall_fscore_support
)
from sklearn.utils.class_weight import compute_class_weight

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow:", tf.__version__)

# =========================
# 2) DATASET PATH
# =========================

dataset_path = "/kaggle/input/datasets/uwrfkaggler/ravdess-emotional-speech-audio"

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"Dataset path not found: {dataset_path}")

print("Dataset path found.")

# =========================
# 3) EMOTION MAP
# =========================

emotion_dict = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

# =========================
# 4) COLLECT FILES
# =========================

file_paths = []
labels = []

for root, _, files in os.walk(dataset_path):
    for file in files:
        if file.lower().endswith(".wav"):
            parts = file.split("-")
            if len(parts) >= 3 and parts[2] in emotion_dict:
                file_paths.append(os.path.join(root, file))
                labels.append(emotion_dict[parts[2]])

df = pd.DataFrame({"path": file_paths, "label": labels})

print("Total audio files:", len(df))
print("\nClass distribution:")
print(df["label"].value_counts())

if len(df) == 0:
    raise ValueError("No WAV files found. Check the dataset path.")

# =========================
# 5) LABEL ENCODING
# =========================

le = LabelEncoder()
y_all = le.fit_transform(df["label"].values)
class_names = le.classes_
num_classes = len(class_names)

print("\nClasses:", list(class_names))
print("Num classes:", num_classes)

if num_classes < 2:
    raise ValueError("Need at least two classes.")

# =========================
# 6) TRAIN / VAL / TEST SPLIT
# =========================

train_files, temp_files, train_labels, temp_labels = train_test_split(
    df["path"].values,
    y_all,
    test_size=0.20,
    random_state=SEED,
    stratify=y_all
)

val_files, test_files, val_labels, test_labels = train_test_split(
    temp_files,
    temp_labels,
    test_size=0.50,
    random_state=SEED,
    stratify=temp_labels
)

print("\nSplit sizes:")
print("Train:", len(train_files))
print("Val:  ", len(val_files))
print("Test: ", len(test_files))

# =========================
# 7) AUDIO AUGMENTATION
# =========================

def augment_audio(audio, sr):
    choice = random.choice(["noise", "shift", "pitch", "stretch"])
    try:
        if choice == "noise":
            noise = 0.005 * np.random.randn(len(audio))
            return audio + noise

        if choice == "shift":
            shift = np.random.randint(-int(0.2 * sr), int(0.2 * sr))
            return np.roll(audio, shift)

        if choice == "pitch":
            steps = np.random.uniform(-2, 2)
            return librosa.effects.pitch_shift(audio, sr=sr, n_steps=steps)

        if choice == "stretch":
            rate = np.random.uniform(0.85, 1.15)
            return librosa.effects.time_stretch(audio, rate=rate)

    except Exception:
        return audio

    return audio

# =========================
# 8) FEATURE EXTRACTION
#    MFCC + Delta + Delta-Delta
# =========================

N_MFCC = 40
MAX_LEN = 173   # fixed time dimension

def pad_or_truncate(mat, max_len=MAX_LEN):
    if mat.shape[1] < max_len:
        pad_width = max_len - mat.shape[1]
        mat = np.pad(mat, ((0, 0), (0, pad_width)), mode="constant")
    else:
        mat = mat[:, :max_len]
    return mat

def load_audio(file_path):
    try:
        audio, sr = librosa.load(file_path, duration=3, offset=0.5)
        if audio is None or len(audio) == 0:
            return None, None
        return audio, sr
    except Exception:
        return None, None

def extract_features_from_audio(audio, sr):
    try:
        mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=N_MFCC)
        delta = librosa.feature.delta(mfcc)
        delta2 = librosa.feature.delta(mfcc, order=2)

        mfcc = pad_or_truncate(mfcc)
        delta = pad_or_truncate(delta)
        delta2 = pad_or_truncate(delta2)

        feat = np.stack([mfcc, delta, delta2], axis=-1).astype(np.float32)  # (40,173,3)
        return feat
    except Exception:
        return None

# =========================
# 9) BUILD DATASET
# =========================

def build_dataset(file_list, label_list, augment=False, show_progress=True):
    X, y = [], []

    for i, (fp, lbl) in enumerate(zip(file_list, label_list), start=1):
        audio, sr = load_audio(fp)
        if audio is None:
            continue

        feat = extract_features_from_audio(audio, sr)
        if feat is not None:
            X.append(feat)
            y.append(lbl)

        if augment:
            aug_audio = augment_audio(audio, sr)
            feat_aug = extract_features_from_audio(aug_audio, sr)
            if feat_aug is not None:
                X.append(feat_aug)
                y.append(lbl)

        if show_progress and i % 100 == 0:
            print(f"Processed {i}/{len(file_list)} files")

    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int32)

print("\nExtracting training features...")
X_train, y_train = build_dataset(train_files, train_labels, augment=True)

print("\nExtracting validation features...")
X_val, y_val = build_dataset(val_files, val_labels, augment=False)

print("\nExtracting test features...")
X_test, y_test = build_dataset(test_files, test_labels, augment=False)

# =========================
# 10) SANITY CHECKS
# =========================

print("\nSanity checks:")
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)

print("y_train:", y_train.shape)
print("y_val:  ", y_val.shape)
print("y_test: ", y_test.shape)

if len(X_train) == 0 or len(X_val) == 0 or len(X_test) == 0:
    raise ValueError("One of the splits has no extracted features.")

expected_shape = (N_MFCC, MAX_LEN, 3)
if X_train.shape[1:] != expected_shape:
    raise ValueError(f"Unexpected input shape. Expected {expected_shape}, got {X_train.shape[1:]}")

if np.isnan(X_train).any() or np.isnan(X_val).any() or np.isnan(X_test).any():
    raise ValueError("NaN found in extracted features.")

print("\nFeature extraction successful.")

# =========================
# 11) NORMALIZATION
# =========================

train_mean = X_train.mean(axis=(0, 1, 2), keepdims=True).astype(np.float32)
train_std = (X_train.std(axis=(0, 1, 2), keepdims=True) + 1e-8).astype(np.float32)

X_train = (X_train - train_mean) / train_std
X_val   = (X_val - train_mean) / train_std
X_test  = (X_test - train_mean) / train_std

print("\nNormalization done.")
print("Train mean:", float(X_train.mean()))
print("Train std :", float(X_train.std()))

# =========================
# 12) ONE-HOT ENCODING
# =========================

y_train_cat = to_categorical(y_train, num_classes=num_classes)
y_val_cat   = to_categorical(y_val, num_classes=num_classes)
y_test_cat  = to_categorical(y_test, num_classes=num_classes)

# =========================
# 13) CLASS BALANCING
# =========================

classes = np.unique(y_train)
class_weights_arr = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)
class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
sample_weights = np.array([class_weight_dict[int(lbl)] for lbl in y_train], dtype=np.float32)

print("\nClass weights:")
print(class_weight_dict)

# =========================
# 14) ADVANCED LOSS: FOCAL LOSS
# =========================

def categorical_focal_loss(gamma=2.0, alpha=0.25, label_smoothing=0.05):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        ncls = tf.cast(tf.shape(y_true)[-1], tf.float32)
        y_true = y_true * (1.0 - label_smoothing) + label_smoothing / ncls

        y_pred = tf.clip_by_value(y_pred, K.epsilon(), 1.0 - K.epsilon())
        ce = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1.0 - y_pred, gamma)

        return tf.reduce_sum(weight * ce, axis=-1)
    return loss

# =========================
# 15) MODEL
# =========================

def build_cnn_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    x = layers.Conv2D(32, (3, 3), padding="same", use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.20)(x)

    x = layers.Conv2D(64, (3, 3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.25)(x)

    x = layers.Conv2D(128, (3, 3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.30)(x)

    x = layers.Conv2D(256, (3, 3), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(256, activation="relu", kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dropout(0.40)(x)

    x = layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dropout(0.30)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

model = build_cnn_model(X_train.shape[1:], num_classes)

try:
    optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-5)
except Exception:
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model.compile(
    optimizer=optimizer,
    loss=categorical_focal_loss(gamma=2.0, alpha=0.25, label_smoothing=0.05),
    metrics=["accuracy"]
)

print("\nModel summary:")
model.summary()

# =========================
# 16) CALLBACKS
# =========================

callbacks = [
    EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1),
    ModelCheckpoint("best_emotion_recognition_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1)
]

# =========================
# 17) TRAIN
# =========================

history = model.fit(
    X_train,
    y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=60,
    batch_size=32,
    sample_weight=sample_weights,
    callbacks=callbacks,
    verbose=1
)

# =========================
# 18) EVALUATION
# =========================

test_loss, test_acc = model.evaluate(X_test, y_test_cat, verbose=0)
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")

y_prob = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_prob, axis=1)
y_true = y_test

accuracy = accuracy_score(y_true, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average="macro", zero_division=0
)

print("\nFinal Metrics:")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-score : {f1:.4f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4, zero_division=0))

# =========================
# 19) PLOTS
# =========================

plt.figure(figsize=(10, 4))
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Val Accuracy")
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="Greens",
            xticklabels=class_names, yticklabels=class_names)
plt.title("Normalized Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# =========================
# 20) SAVE MODEL + CLASS NAMES
# =========================

model.save("emotion_recognition_best.keras")

with open("label_classes.json", "w") as f:
    json.dump(class_names.tolist(), f)

np.save("train_mean.npy", train_mean)
np.save("train_std.npy", train_std)

print("\nSaved model as emotion_recognition_best.keras")
print("Saved label classes as label_classes.json")
print("Saved normalization stats as train_mean.npy and train_std.npy")

# =========================
# 21) FIXED PREDICTION FUNCTION
# =========================

def predict_emotion(audio_path):
    audio, sr = load_audio(audio_path)
    if audio is None:
        return "Audio load failed", 0.0

    feat = extract_features_from_audio(audio, sr)
    if feat is None:
        return "Feature extraction failed", 0.0

    # Normalize with training statistics
    feat = (feat - train_mean.squeeze()) / train_std.squeeze()

    # Add batch dimension
    feat = np.expand_dims(feat, axis=0).astype(np.float32)

    # Sanity check
    print("Prediction input shape:", feat.shape)

    prob = model.predict(feat, verbose=0)[0]
    pred_idx = int(np.argmax(prob))
    pred_label = le.inverse_transform([pred_idx])[0]
    confidence = float(np.max(prob))

    return pred_label, confidence

# =========================
# 22) TEST SINGLE PREDICTION
# =========================

sample_path = test_files[0]
pred_label, pred_conf = predict_emotion(sample_path)

print("\nSample Prediction Test:")
print("File:", sample_path)
print("Predicted Emotion:", pred_label)
print("Confidence:", round(pred_conf, 4))

# =========================
# 23) FINAL SANITY CHECK
# =========================

print("\n===================================================")
print("PIPELINE COMPLETED SUCCESSFULLY")
print("Model trained, evaluated, and prediction fixed.")
print("===================================================")
# Out:
# TensorFlow: 2.19.0
# Dataset path found.
# Total audio files: 2880
#
# Class distribution:
# label
# surprised    384
# disgust      384
# fearful      384
# sad          384
# happy        384
# calm         384
# angry        384
# neutral      192
# Name: count, dtype: int64
#
# Classes: ['angry', 'calm', 'disgust', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# Num classes: 8
#
# Split sizes:
# Train: 2304
# Val:   288
# Test:  288
#
# Extracting training features...
# Processed 100/2304 files
# Processed 200/2304 files
# Processed 300/2304 files
# Processed 400/2304 files
# Processed 500/2304 files
# Processed 600/2304 files
# Processed 700/2304 files
# Processed 800/2304 files
# Processed 900/2304 files
# Processed 1000/2304 files
# Processed 1100/2304 files
# Processed 1200/2304 files
# Processed 1300/2304 files
# Processed 1400/2304 files
# Processed 1500/2304 files
# Processed 1600/2304 files
# Processed 1700/2304 files
# Processed 1800/2304 files
# Processed 1900/2304 files
# Processed 2000/2304 files
# Processed 2100/2304 files
# Processed 2200/2304 files
# Processed 2300/2304 files
#
# Extracting validation features...
# Processed 100/288 files
# Processed 200/288 files
#
# Extracting test features...
# Processed 100/288 files
# Processed 200/288 files
#
# Sanity checks:
# X_train: (4608, 40, 173, 3)
# X_val:   (288, 40, 173, 3)
# X_test:  (288, 40, 173, 3)
# y_train: (4608,)
# y_val:   (288,)
# y_test:  (288,)
#
# Feature extraction successful.
#
# Normalization done.
# Train mean: 0.00017071249021682888
# Train std : 1.0206156969070435
#
# Class weights:
# {0: 0.935064935064935, 1: 0.9381107491856677, 2: 0.9381107491856677, 3: 0.9381107491856677, 4: 0.9381107491856677, 5: 1.87012987012987, 6: 0.9381107491856677, 7: 0.9381107491856677}
#
# Model summary:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 40, 173, 3)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 40, 173, 32)    │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 40, 173, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 40, 173, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 20, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 20, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 20, 86, 64)     │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 20, 86, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 20, 86, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 10, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 10, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 10, 43, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 10, 43, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 10, 43, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 5, 21, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 5, 21, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 5, 21, 256)     │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 5, 21, 256)     │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 5, 21, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 489,576 (1.87 MB)
#  Trainable params: 488,616 (1.86 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1760 - loss: 0.4212
# Epoch 1: val_accuracy improved from None to 0.20486, saving model to best_emotion_recognition_model.keras
#
# Epoch 1: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.2253 - loss: 0.3912 - val_accuracy: 0.2049 - val_loss: 0.3864 - learning_rate: 0.0010
# Epoch 2/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3300 - loss: 0.3312
# Epoch 2: val_accuracy did not improve from 0.20486
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3711 - loss: 0.3168 - val_accuracy: 0.1875 - val_loss: 0.8371 - learning_rate: 0.0010
# Epoch 3/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4019 - loss: 0.2894
# Epoch 3: val_accuracy improved from 0.20486 to 0.23958, saving model to best_emotion_recognition_model.keras
#
# Epoch 3: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4269 - loss: 0.2811 - val_accuracy: 0.2396 - val_loss: 0.6773 - learning_rate: 0.0010
# Epoch 4/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4528 - loss: 0.2699
# Epoch 4: val_accuracy improved from 0.23958 to 0.34722, saving model to best_emotion_recognition_model.keras
#
# Epoch 4: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4638 - loss: 0.2623 - val_accuracy: 0.3472 - val_loss: 0.4412 - learning_rate: 0.0010
# Epoch 5/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4778 - loss: 0.2502
# Epoch 5: val_accuracy improved from 0.34722 to 0.55208, saving model to best_emotion_recognition_model.keras
#
# Epoch 5: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4857 - loss: 0.2458 - val_accuracy: 0.5521 - val_loss: 0.2227 - learning_rate: 0.0010
# Epoch 6/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4980 - loss: 0.2428
# Epoch 6: val_accuracy did not improve from 0.55208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5156 - loss: 0.2353 - val_accuracy: 0.4062 - val_loss: 0.2937 - learning_rate: 0.0010
# Epoch 7/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5224 - loss: 0.2309
# Epoch 7: val_accuracy did not improve from 0.55208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5451 - loss: 0.2206 - val_accuracy: 0.4722 - val_loss: 0.2581 - learning_rate: 0.0010
# Epoch 8/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5531 - loss: 0.2195
# Epoch 8: val_accuracy did not improve from 0.55208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5803 - loss: 0.2098 - val_accuracy: 0.5104 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 9/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5728 - loss: 0.2101
# Epoch 9: val_accuracy did not improve from 0.55208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5894 - loss: 0.2020 - val_accuracy: 0.4479 - val_loss: 0.3587 - learning_rate: 0.0010
# Epoch 10/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5840 - loss: 0.2012
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_accuracy did not improve from 0.55208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6070 - loss: 0.1934 - val_accuracy: 0.4792 - val_loss: 0.2865 - learning_rate: 0.0010
# Epoch 11/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6292 - loss: 0.1848
# Epoch 11: val_accuracy improved from 0.55208 to 0.67361, saving model to best_emotion_recognition_model.keras
#
# Epoch 11: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6554 - loss: 0.1760 - val_accuracy: 0.6736 - val_loss: 0.1689 - learning_rate: 5.0000e-04
# Epoch 12/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6435 - loss: 0.1747
# Epoch 12: val_accuracy improved from 0.67361 to 0.70139, saving model to best_emotion_recognition_model.keras
#
# Epoch 12: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6636 - loss: 0.1687 - val_accuracy: 0.7014 - val_loss: 0.1634 - learning_rate: 5.0000e-04
# Epoch 13/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6731 - loss: 0.1642
# Epoch 13: val_accuracy improved from 0.70139 to 0.70486, saving model to best_emotion_recognition_model.keras
#
# Epoch 13: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6879 - loss: 0.1611 - val_accuracy: 0.7049 - val_loss: 0.1624 - learning_rate: 5.0000e-04
# Epoch 14/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6887 - loss: 0.1605
# Epoch 14: val_accuracy did not improve from 0.70486
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6984 - loss: 0.1562 - val_accuracy: 0.7049 - val_loss: 0.1570 - learning_rate: 5.0000e-04
# Epoch 15/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6911 - loss: 0.1591
# Epoch 15: val_accuracy did not improve from 0.70486
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7038 - loss: 0.1542 - val_accuracy: 0.7049 - val_loss: 0.1481 - learning_rate: 5.0000e-04
# Epoch 16/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7284 - loss: 0.1501
# Epoch 16: val_accuracy improved from 0.70486 to 0.71181, saving model to best_emotion_recognition_model.keras
#
# Epoch 16: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7283 - loss: 0.1485 - val_accuracy: 0.7118 - val_loss: 0.1738 - learning_rate: 5.0000e-04
# Epoch 17/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7162 - loss: 0.1495
# Epoch 17: val_accuracy did not improve from 0.71181
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7326 - loss: 0.1448 - val_accuracy: 0.6875 - val_loss: 0.1643 - learning_rate: 5.0000e-04
# Epoch 18/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7387 - loss: 0.1431
# Epoch 18: val_accuracy improved from 0.71181 to 0.73958, saving model to best_emotion_recognition_model.keras
#
# Epoch 18: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7415 - loss: 0.1421 - val_accuracy: 0.7396 - val_loss: 0.1387 - learning_rate: 5.0000e-04
# Epoch 19/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7403 - loss: 0.1424
# Epoch 19: val_accuracy improved from 0.73958 to 0.76389, saving model to best_emotion_recognition_model.keras
#
# Epoch 19: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7487 - loss: 0.1386 - val_accuracy: 0.7639 - val_loss: 0.1249 - learning_rate: 5.0000e-04
# Epoch 20/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7677 - loss: 0.1356
# Epoch 20: val_accuracy did not improve from 0.76389
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7676 - loss: 0.1335 - val_accuracy: 0.7604 - val_loss: 0.1292 - learning_rate: 5.0000e-04
# Epoch 21/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7450 - loss: 0.1383
# Epoch 21: val_accuracy did not improve from 0.76389
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7537 - loss: 0.1348 - val_accuracy: 0.7431 - val_loss: 0.1484 - learning_rate: 5.0000e-04
# Epoch 22/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7702 - loss: 0.1304
# Epoch 22: val_accuracy did not improve from 0.76389
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7737 - loss: 0.1307 - val_accuracy: 0.6875 - val_loss: 0.1667 - learning_rate: 5.0000e-04
# Epoch 23/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7711 - loss: 0.1306
# Epoch 23: val_accuracy did not improve from 0.76389
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7786 - loss: 0.1299 - val_accuracy: 0.7500 - val_loss: 0.1350 - learning_rate: 5.0000e-04
# Epoch 24/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7771 - loss: 0.1264
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 24: val_accuracy did not improve from 0.76389
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7847 - loss: 0.1254 - val_accuracy: 0.7292 - val_loss: 0.1442 - learning_rate: 5.0000e-04
# Epoch 25/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7947 - loss: 0.1210
# Epoch 25: val_accuracy improved from 0.76389 to 0.77083, saving model to best_emotion_recognition_model.keras
#
# Epoch 25: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7977 - loss: 0.1199 - val_accuracy: 0.7708 - val_loss: 0.1361 - learning_rate: 2.5000e-04
# Epoch 26/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8214 - loss: 0.1172
# Epoch 26: val_accuracy did not improve from 0.77083
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8166 - loss: 0.1160 - val_accuracy: 0.7604 - val_loss: 0.1328 - learning_rate: 2.5000e-04
# Epoch 27/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8121 - loss: 0.1162
# Epoch 27: val_accuracy did not improve from 0.77083
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8149 - loss: 0.1154 - val_accuracy: 0.7674 - val_loss: 0.1166 - learning_rate: 2.5000e-04
# Epoch 28/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8153 - loss: 0.1118
# Epoch 28: val_accuracy improved from 0.77083 to 0.80208, saving model to best_emotion_recognition_model.keras
#
# Epoch 28: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8223 - loss: 0.1115 - val_accuracy: 0.8021 - val_loss: 0.1296 - learning_rate: 2.5000e-04
# Epoch 29/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8210 - loss: 0.1125
# Epoch 29: val_accuracy did not improve from 0.80208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8223 - loss: 0.1129 - val_accuracy: 0.7847 - val_loss: 0.1088 - learning_rate: 2.5000e-04
# Epoch 30/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8256 - loss: 0.1138
# Epoch 30: val_accuracy did not improve from 0.80208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8268 - loss: 0.1132 - val_accuracy: 0.7917 - val_loss: 0.1205 - learning_rate: 2.5000e-04
# Epoch 31/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8296 - loss: 0.1079
# Epoch 31: val_accuracy did not improve from 0.80208
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8336 - loss: 0.1077 - val_accuracy: 0.7778 - val_loss: 0.1275 - learning_rate: 2.5000e-04
# Epoch 32/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8310 - loss: 0.1098
# Epoch 32: val_accuracy improved from 0.80208 to 0.81250, saving model to best_emotion_recognition_model.keras
#
# Epoch 32: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8368 - loss: 0.1083 - val_accuracy: 0.8125 - val_loss: 0.1080 - learning_rate: 2.5000e-04
# Epoch 33/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8310 - loss: 0.1076
# Epoch 33: val_accuracy did not improve from 0.81250
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8357 - loss: 0.1072 - val_accuracy: 0.7604 - val_loss: 0.1249 - learning_rate: 2.5000e-04
# Epoch 34/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8379 - loss: 0.1079
# Epoch 34: val_accuracy did not improve from 0.81250
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8435 - loss: 0.1064 - val_accuracy: 0.7812 - val_loss: 0.1123 - learning_rate: 2.5000e-04
# Epoch 35/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8474 - loss: 0.1063
# Epoch 35: val_accuracy improved from 0.81250 to 0.82292, saving model to best_emotion_recognition_model.keras
#
# Epoch 35: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8442 - loss: 0.1061 - val_accuracy: 0.8229 - val_loss: 0.1193 - learning_rate: 2.5000e-04
# Epoch 36/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8374 - loss: 0.1058
# Epoch 36: val_accuracy did not improve from 0.82292
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8388 - loss: 0.1051 - val_accuracy: 0.7778 - val_loss: 0.1254 - learning_rate: 2.5000e-04
# Epoch 37/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8442 - loss: 0.1045
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 37: val_accuracy did not improve from 0.82292
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8498 - loss: 0.1039 - val_accuracy: 0.7535 - val_loss: 0.1287 - learning_rate: 2.5000e-04
# Epoch 38/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8470 - loss: 0.1033
# Epoch 38: val_accuracy did not improve from 0.82292
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8526 - loss: 0.1014 - val_accuracy: 0.8194 - val_loss: 0.1043 - learning_rate: 1.2500e-04
# Epoch 39/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8614 - loss: 0.0988
# Epoch 39: val_accuracy did not improve from 0.82292
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8631 - loss: 0.0994 - val_accuracy: 0.8160 - val_loss: 0.1121 - learning_rate: 1.2500e-04
# Epoch 40/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8698 - loss: 0.0980
# Epoch 40: val_accuracy did not improve from 0.82292
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8709 - loss: 0.0981 - val_accuracy: 0.8125 - val_loss: 0.1077 - learning_rate: 1.2500e-04
# Epoch 41/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8574 - loss: 0.1008
# Epoch 41: val_accuracy improved from 0.82292 to 0.82986, saving model to best_emotion_recognition_model.keras
#
# Epoch 41: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8624 - loss: 0.0996 - val_accuracy: 0.8299 - val_loss: 0.1005 - learning_rate: 1.2500e-04
# Epoch 42/60
# 143/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8455 - loss: 0.1014
# Epoch 42: val_accuracy did not improve from 0.82986
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8539 - loss: 0.0995 - val_accuracy: 0.8160 - val_loss: 0.1042 - learning_rate: 1.2500e-04
# Epoch 43/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8754 - loss: 0.0971
# Epoch 43: val_accuracy did not improve from 0.82986
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8772 - loss: 0.0958 - val_accuracy: 0.8264 - val_loss: 0.1031 - learning_rate: 1.2500e-04
# Epoch 44/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8675 - loss: 0.0981
# Epoch 44: val_accuracy improved from 0.82986 to 0.86458, saving model to best_emotion_recognition_model.keras
#
# Epoch 44: finished saving model to best_emotion_recognition_model.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8659 - loss: 0.0982 - val_accuracy: 0.8646 - val_loss: 0.0945 - learning_rate: 1.2500e-04
# Epoch 45/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8756 - loss: 0.0970
# Epoch 45: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8763 - loss: 0.0968 - val_accuracy: 0.8194 - val_loss: 0.1068 - learning_rate: 1.2500e-04
# Epoch 46/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8669 - loss: 0.0964
# Epoch 46: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8698 - loss: 0.0964 - val_accuracy: 0.8194 - val_loss: 0.1017 - learning_rate: 1.2500e-04
# Epoch 47/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8752 - loss: 0.0968
# Epoch 47: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8709 - loss: 0.0968 - val_accuracy: 0.8229 - val_loss: 0.1059 - learning_rate: 1.2500e-04
# Epoch 48/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8602 - loss: 0.0978
# Epoch 48: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8700 - loss: 0.0958 - val_accuracy: 0.8542 - val_loss: 0.1018 - learning_rate: 1.2500e-04
# Epoch 49/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8712 - loss: 0.0961
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 49: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8770 - loss: 0.0950 - val_accuracy: 0.8333 - val_loss: 0.1003 - learning_rate: 1.2500e-04
# Epoch 50/60
# 141/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8871 - loss: 0.0947
# Epoch 50: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8822 - loss: 0.0952 - val_accuracy: 0.8160 - val_loss: 0.1111 - learning_rate: 6.2500e-05
# Epoch 51/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8767 - loss: 0.0942
# Epoch 51: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8796 - loss: 0.0938 - val_accuracy: 0.8333 - val_loss: 0.1019 - learning_rate: 6.2500e-05
# Epoch 52/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8742 - loss: 0.0922
# Epoch 52: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8789 - loss: 0.0927 - val_accuracy: 0.7986 - val_loss: 0.1078 - learning_rate: 6.2500e-05
# Epoch 53/60
# 140/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8812 - loss: 0.0934
# Epoch 53: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8843 - loss: 0.0930 - val_accuracy: 0.8368 - val_loss: 0.1042 - learning_rate: 6.2500e-05
# Epoch 54/60
# 142/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8795 - loss: 0.0922
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 54: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8811 - loss: 0.0919 - val_accuracy: 0.8264 - val_loss: 0.1027 - learning_rate: 6.2500e-05
# Epoch 55/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8702 - loss: 0.0944
# Epoch 55: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8796 - loss: 0.0933 - val_accuracy: 0.8507 - val_loss: 0.0985 - learning_rate: 3.1250e-05
# Epoch 56/60
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8820 - loss: 0.0917
# Epoch 56: val_accuracy did not improve from 0.86458
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8880 - loss: 0.0898 - val_accuracy: 0.8229 - val_loss: 0.1036 - learning_rate: 3.1250e-05
# Epoch 56: early stopping
# Restoring model weights from the end of the best epoch: 44.
#
# Test Loss: 0.0984
# Test Accuracy: 0.8576
#
# Final Metrics:
# Accuracy : 0.8576
# Precision: 0.8664
# Recall   : 0.8539
# F1-score : 0.8486
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry     0.9722    0.9211    0.9459        38
#         calm     0.6667    1.0000    0.8000        38
#      disgust     0.9697    0.8421    0.9014        38
#      fearful     0.8444    0.9744    0.9048        39
#        happy     0.9211    0.8974    0.9091        39
#      neutral     0.6818    0.7895    0.7317        19
#          sad     0.8750    0.5385    0.6667        39
#    surprised     1.0000    0.8684    0.9296        38
#
#     accuracy                         0.8576       288
#    macro avg     0.8664    0.8539    0.8486       288
# weighted avg     0.8787    0.8576    0.8561       288
# Saved model as emotion_recognition_best.keras
# Saved label classes as label_classes.json
# Saved normalization stats as train_mean.npy and train_std.npy
# Prediction input shape: (1, 40, 173, 3)
#
# Sample Prediction Test:
# File: /kaggle/input/datasets/uwrfkaggler/ravdess-emotional-speech-audio/Actor_12/03-01-03-01-02-01-12.wav
# Predicted Emotion: happy
# Confidence: 0.8033
#
# ===================================================
# PIPELINE COMPLETED SUCCESSFULLY
# Model trained, evaluated, and prediction fixed.
# ===================================================
